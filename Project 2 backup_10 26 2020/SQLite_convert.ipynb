# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
df=pd.read_csv('Resources/Denver_beer_wine_whiskey-clean.csv')
df
# Out:
#                          id                               name_  \
# 0    DNKucP0SZ7ea-nOZgetFhg        Great Divide Brewing Company
# 1    u0lEXYd_cdf2_Zg99rSM9w           Vine Street Pub & Brewery
# 2    3asUEG-iok2bunLBp1O_mw           Lowdown Brewery + Kitchen
# 3    _jUBigRXts5f3b7ayKLI6Q         The Post Brewing Co. Denver
# 4    ofPa6i98oFCiq0zoWj1cvw                 Black Shirt Brewing
# ..                      ...                                 ...
# 112  UbISbydUifsWeP6ADYZkRw               Rising Sun Distillery
# 113  LHw3BtwW7om_8TbrEr9psg           Tighe Brothers Distillery
# 114  AT40GuKOGj-KTBtJnIdrzw             Devil's Head Distillery
# 115  JNfwcgL65DJtPt_e4Pq_Ig  Talnua Distillery and Tasting Room
# 116  EulPLFbdJqfrFBxpu6x0Eg                 Molly Brown Spirits
#
#                                              image_url  is_closed  \
# 0    https://s3-media3.fl.yelpcdn.com/bphoto/KAccMu...      False
# ...

# %%
df.keys()
# Out:
# Index(['id', 'name_', 'image_url', 'is_closed', 'url', 'review_count',
#        'category', 'rating', 'price', 'display_phone', 'latitude', 'longitude',
#        'address1', 'address2', 'address3', 'city', 'zip_code', 'country',
#        'state_'],
#       dtype='object')

# %%
engine = create_engine("sqlite:///Denver_beer_wine_whiskey.sqlite", echo=True)
sqlite_conn = engine.connect()
# Out:
# 2020-10-20 19:21:10,349 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-10-20 19:21:10,350 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-20 19:21:10,352 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-10-20 19:21:10,352 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table='denverBeer2'
df.to_sql(sqlite_table, sqlite_conn, if_exists='fail')
# Out:
# 2020-10-20 19:21:23,284 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("denverBeer2")
# 2020-10-20 19:21:23,285 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-20 19:21:23,288 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("denverBeer2")
# 2020-10-20 19:21:23,289 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-20 19:21:23,295 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "denverBeer2" (
# 	"index" BIGINT,
# 	id TEXT,
# 	name_ TEXT,
# 	image_url TEXT,
# 	is_closed BOOLEAN,
# 	url TEXT,
# 	review_count BIGINT,
# 	category TEXT,
# 	rating FLOAT,
# 	price TEXT,
# 	display_phone TEXT,
# 	latitude FLOAT,
# 	longitude FLOAT,
# 	address1 TEXT,
# 	address2 TEXT,
# 	address3 TEXT,
# 	city TEXT,
# 	zip_code BIGINT,
# 	country TEXT,
# 	state_ TEXT,
# 	CHECK (is_closed IN (0, 1))
# )
#
#
# 2020-10-20 19:21:23,297 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-20 19:21:23,315 INFO sqlalchemy.engine.base.Engine COMMIT
# ...

# %%
engine.execute('SELECT * FROM denverBeer2 LIMIT 5').fetchall()
# Out:
# 2020-10-20 19:58:05,534 INFO sqlalchemy.engine.base.Engine SELECT * FROM denverBeer2 LIMIT 5
# 2020-10-20 19:58:05,535 INFO sqlalchemy.engine.base.Engine ()
# [(0, 'DNKucP0SZ7ea-nOZgetFhg', 'Great Divide Brewing Company', 'https://s3-media3.fl.yelpcdn.com/bphoto/KAccMuhlXGS1PqkdUNpGJA/o.jpg', 0, 'https://www.yelp.com/biz/great-divide-brewing-company-denver?adjust_creative=2HS7cwZSZjB4KpQC_8JOTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2HS7cwZSZjB4KpQC_8JOTw', 1008, 'Brewery', 4.5, '$', '(303) 296-9460', 39.7539, -104.98846, '2201 Arapahoe St', None, None, 'Denver', 80205, 'US', 'CO'),
# ...
