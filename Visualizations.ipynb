# %%
# historgram of top 10 breweries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func


from flask import Flask, jsonify
from flask_cors import CORS, cross_origin

# %%
#################################################
# Database Setup
#################################################
engine = create_engine("sqlite:///Denver_beer_wine_whiskey.sqlite")

# %%
engine.execute('SELECT * FROM denverBeer2 LIMIT 1').fetchall()
# Out:
# [(0, 'DNKucP0SZ7ea-nOZgetFhg', 'Great Divide Brewing Company', 'https://s3-media3.fl.yelpcdn.com/bphoto/KAccMuhlXGS1PqkdUNpGJA/o.jpg', 0, 'https://www.yelp.com/biz/great-divide-brewing-company-denver?adjust_creative=2HS7cwZSZjB4KpQC_8JOTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2HS7cwZSZjB4KpQC_8JOTw', 1008, 'Brewery', 4.5, '$', '(303) 296-9460', 39.7539, -104.98846, '2201 Arapahoe St', None, None, 'Denver', 80205, 'US', 'CO')]

# %%
r = engine.execute('SELECT name_, rating, review_count FROM denverBeer2 ORDER BY rating DESC LIMIT 20').fetchall() 
df
plt.savefig('image1a')

# %%
df = pd.DataFrame(r, columns=['name_', 'rating', 'review_count'])

# %%
df.sort_values(by='review_count', ascending=False).plot.bar('name_', 'review_count')
plt.savefig('image1b')

# %%
engine = create_engine("sqlite:///Denver_beer_wine_whiskey.sqlite", echo=True)
sqlite_conn = engine.connect()
# Out:
# 2020-10-22 16:49:44,694 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-10-22 16:49:44,694 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-22 16:49:44,696 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-10-22 16:49:44,696 INFO sqlalchemy.engine.base.Engine ()

# %%
r = engine.execute("SELECT name_, rating, review_count, zip_code FROM denverBeer2 ORDER BY zip_code DESC LIMIT 20;").fetchall()
df
plt.savefig('image2a')
# Out:
# 2020-10-22 16:49:45,255 INFO sqlalchemy.engine.base.Engine SELECT name_, rating, review_count, zip_code FROM denverBeer2 ORDER BY zip_code DESC LIMIT 20;
# 2020-10-22 16:49:45,255 INFO sqlalchemy.engine.base.Engine ()

# %%
df = pd.DataFrame(r, columns=['name_', 'rating', 'review_count', 'zip_code'])
df.sort_values(by='zip_code', ascending=False).plot.bar('name_', 'review_count')
plt.savefig('image2b')
